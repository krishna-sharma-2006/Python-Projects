# %% [markdown]
# ## Banking System

# %%
class Account:
    def __init__(self, acc_no, name, balance = 0):
        self.acc_no = acc_no
        self.name = name
        self._balance = balance

    def withdraw(self, amount):
        if self._balance > amount:
            self._balance -= amount
        else:
            raise ValueError("Invalid Amount")

    def deposit(self, amount):
        self._balance += amount

    def get_balance(self):
        return self._balance


class SavingsAccount(Account):
    MIN_BALANCE = 500
    def withdraw_savings(self, amount):
        if self.balace - amount < MIN_BALANCE:
            raise ValueError("The value is invalid...can not withdraw the amount.")
        super().withdraw(amount)


class CurrentAccount(Account):
    OverDraft_limit = 1000

    def withdraw_Current(self, amount):
        if self._balance - amount < OverDraft_limit:
            raise ValueError("INVALID AMOUNT")
        else:
            super().withdraw(amount)

class Bank:
    def __init__(self):
        self.accounts = {}
    def create_acc(self,account):
        if account.acc_no in self.accounts:
            raise ValueError("INVALID ACCOUNT")
        self.accounts[account.acc_no] = account

    def search_acc(self, accno):
        return self.accounts.get(accno)

# %%
class SavingsAccount(Account):
    MIN_BALANCE = 500
    def withdraw_savings(self, amount):
        if self.balace - amount < MIN_BALANCE:
            raise ValueError("The value is invalid...can not withdraw the amount.")
        super().withdraw(amount)

# %%
class CurrentAccount(Account):
    OverDraft_limit = 1000

    def withdraw_Current(self, amount):
        if self._balance - amount < OverDraft_limit:
            raise ValueError("INVALID AMOUNT")
        else:
            super().withdraw(amount)

# %%
class Bank:
    def __init__(self):
        self.accounts = {}
    def create_acc(self,account):
        if account.acc_no in self.accounts:
            raise ValueError("INVALID ACCOUNT")
        self.accounts[account.acc_no] = account

    def search_acc(self, accno):
        return self.accounts.get(accno)

# %%
item = Bank()

# %%
acc1 = SavingsAccount(1, "krishna", 5000)
acc2 = CurrentAccount(2, "Manish", 7000)

# %%
item.accounts
# Out:
# {1: <__main__.SavingsAccount at 0x1191597b250>,
#  2: <__main__.CurrentAccount at 0x11915b76510>}
